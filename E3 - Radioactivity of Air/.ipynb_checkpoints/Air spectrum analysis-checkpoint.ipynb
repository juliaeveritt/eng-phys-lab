# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.constants as const
from scipy.optimize import curve_fit
import operator

# %%
# Colour palette
c = ["#006ba6", "#0496ff", "#82a9a1", "#ffbc42", "#ec674e", "#d81159", "#8f2d56"]

# %%
# Plot settings
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (4,3)  # good default size for column-width figure

# %%
def get_energy(bins):
    return 0.1263 * bins - 0.6

# %% [markdown]
# ## Background readings
# * Coarse gain: x10
# * Fine gain: just under 12.5
# * Integrate: 200 ns
# * Diff: 500 ns

# %%
bin_arr = []
energy_arr = []

# %%
filepath = 'data/background_air.csv'
duration = 650  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

bg_ch = df['ch']  # bin
bg_n = df['n'] / duration  # counts/s

plt.plot(get_energy(bg_ch), bg_n, 'k')
plt.xlabel('Energy [keV]')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Background')
# Out:
# Text(0.5, 1.0, 'Background')

# %% [markdown]
# ## Spectrum 1: short sampling time
# Looking for Pb peak around 351.9 keV (bin 3000) or 77 keV (bin 1000)

# %%
def gaussian(x, h, a, x0, s):
    return h + a * np.exp(-(x - x0) ** 2 / (2 * s ** 2))

# %%
filepath = 'data/air_short.csv'
duration = 1238  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n  # counts/s
dn = np.sqrt(n)

# Look for Pb peak at 351.9 keV
lower_idx = 50
upper_idx = 100

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.axvspan(ch[lower_idx], ch[upper_idx], color=c[1], alpha=0.3)
# plt.axhline(amax, color=c[0])
# plt.axvline(index, color=c[0])

bq_meas1 = amax
dbq_meas1 = np.sqrt(amax)

print(f"Peak position: {index} keV")
print(f"Counts/s: {bq_meas1} +/- {dbq_meas1}")

# Look for Pb peak at 295 keV
lower_idx = 325
upper_idx = 375

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.plot(get_energy(ch), n, 'k')
# plt.plot(ch, n + dn, '--k', alpha=0.5)
plt.xlim(0, 500)
plt.xlabel('Energy [keV]')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Air (2h sample)')
plt.axvspan(ch[lower_idx], ch[upper_idx], color=c[0], alpha=0.3)
# plt.axhline(amax, color=c[0])
# plt.axvline(index, color=c[0])
plt.plot(gaussian(get_energy(x), popt[0], popt[1], popt[2], popt[3]), label="Fit")

bq_meas2 = amax
dbq_meas2 = np.sqrt(amax)

print(f"Peak position: {index} keV")
print(f"Counts/s: {bq_meas2} +/- {dbq_meas2}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Peak position: 50 keV
# Counts/s: 898.3051944824158 +/- 29.971739930848457
# Peak position: 349 keV
# Counts/s: 0.008077544426494346 +/- 0.08987516023070193

# %%
filepath = 'data/air_short.csv'
duration = 1238  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n  # counts / s
dn = np.sqrt(n) / duration

# Look for Pb peak at 77 keV (around bin 1000)
lower_idx = 500
upper_idx = 800

x = get_energy(ch[lower_idx:upper_idx])
y = n[lower_idx:upper_idx]
dy = dn[lower_idx:upper_idx]

plt.plot(x, y, label="Data")

guess = [0, 0.05, 77, 2]  # h, a, x0, s
# plt.plot(x, gaussian(x, guess[0], guess[1], guess[2], guess[3]), '--', label="Guess")

popt, pcov = curve_fit(gaussian, x, y, p0=guess, maxfev=5000)
fit = gaussian(x, popt[0], popt[1], popt[2], popt[3])
r2 = 1 - (np.sum((y-fit)**2) / np.sum((y - np.mean(y)) ** 2))
plt.plot(x, fit, label=f"Fit (R2={r2:.2f})")

plt.title("77 keV peak")
plt.xlabel("Energy (keV)")
plt.ylabel("Counts/s")
plt.legend()

m77 = popt[2]
dm77 = np.sqrt(pcov[2][2])

h77 = popt[1]
dh77 = np.sqrt(pcov[1][1])

print(f"Mean: {m77:.2f} +/- {dm77:.2f} (keV)")
print(f"Height: {h77:.4f} +/- {dh77:.4f} (counts / s)")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Mean: 76.17 +/- 0.07 (keV)
# Height: 0.0317 +/- 0.0010 (counts / s)

# %%
# Look for Pb peak at 351.9 keV (around bin 3000)
lower_idx = 2500
upper_idx = 3000
guess = [0, 0.015, 2800, 25]  # h, a, x0, s

x = get_energy(ch[lower_idx:upper_idx])
y = n[lower_idx:upper_idx]
dy = dn[lower_idx:upper_idx]

plt.plot(x, y, label="Data")


# plt.plot(x, gaussian(x, guess[0], guess[1], guess[2], guess[3]), '--', label="Guess")

popt, pcov = curve_fit(gaussian, x, y, p0=guess, maxfev=5000)
fit = gaussian(x, popt[0], popt[1], popt[2], popt[3])
r2 = 1 - (np.sum((y-fit)**2) / np.sum((y - np.mean(y)) ** 2))
plt.plot(x, fit, label=f"Fit (R2={r2:.2f})")

plt.title("77 keV peak")
plt.xlabel("Energy (keV)")
plt.ylabel("Counts/s")
plt.legend()

m77 = popt[2]
dm77 = np.sqrt(pcov[2][2])

h77 = popt[1]
dh77 = np.sqrt(pcov[1][1])

print(f"Mean: {popt[2]:.1f} +/- {np.sqrt(pcov[2][2]):.1f} (channels)")
print(f"Mean: {get_energy(popt[2])} +/- {get_energy(np.sqrt(pcov[2][2])):.1f} (keV)")
print(f"Height: {popt[1]} +/- {np.sqrt(pcov[1][1])} (counts / s)")
# Out:
# Mean: 2800.0 +/- inf (channels)
# Mean: 353.03999999999996 +/- inf (keV)
# Height: 0.015 +/- inf (counts / s)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# ## Spectrum 2: long sampling time

# %%
filepath = 'data/air_long.csv'
duration = 1800  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n  # counts/s
dn = np.sqrt(n)

plt.plot(get_energy(ch), n, 'k')
# plt.plot(ch, n + dn, '--k', alpha=0.5)
plt.xlim(0, 900)
plt.xlabel('Energy [keV]')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Air (40h sample)')

# Look for Pb peak at 77 keV
lower_idx = 50
upper_idx = 100

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.axvspan(ch[lower_idx], ch[upper_idx], color=c[3], alpha=0.3)
# plt.axhline(amax, color=c[0])
# plt.axvline(index, color=c[0])

bq_meas1 = amax
dbq_meas1 = np.sqrt(amax)

print(f"Peak position: {index} keV")
print(f"Counts/s: {bq_meas1} +/- {dbq_meas1}")

# Look for Pb peak at 238 keV
lower_idx = 220
upper_idx = 250

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.axvspan(ch[lower_idx], ch[upper_idx], color=c[4], alpha=0.3)
# plt.axhline(amax, color=c[0])
# plt.axvline(index, color=c[0])

bq_meas2 = amax
dbq_meas2 = np.sqrt(amax)

print(f"Peak position: {index} keV")
print(f"Counts/s: {bq_meas2} +/- {dbq_meas2}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Peak position: 68 keV
# Counts/s: 0.029914529914529905 +/- 0.17295817388759024
# Peak position: 246 keV
# Counts/s: 0.0044444444444444444 +/- 0.06666666666666667
