# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.constants as const

# %%
# Colour palette
cs = ["#006ba6", "#0496ff", "#82a9a1", "#ffbc42", "#ec674e", "#d81159", "#8f2d56"]

# %%
# Plot settings
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (4,3)  # good default size for column-width figure

# %% [markdown]
# ## Background readings
# * Coarse gain: x10
# * Fine gain: just under 12.5
# * Integrate: 200 ns
# * Diff: 500 ns

# %%
bin_arr = []
energy_arr = []

# %%
filepath = 'data/background_x10.csv'
duration = 1763  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

bg_ch = df['ch']  # bin
bg_n = df['n'] / duration  # counts/s

plt.plot(bg_ch, bg_n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Background')
# Out:
# Text(0.5, 1.0, 'Background')

# %% [markdown]
# ## Sample 1: Cs-137
# Peak corresponds to 662 keV.

# %%
filepath = 'data/cs137_x10.csv'
duration = 260  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n  # counts/s
dn = np.sqrt(df['n']) / duration

plt.plot(ch, n, 'k')
# plt.plot(ch, n + dn, '--k', alpha=0.5)
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Cs-137')

lower_idx = 5000
upper_idx = 5500

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[0], alpha=0.3)
# plt.axhline(amax, color=c[0])
# plt.axvline(index, color=c[0])

bq_meas1 = amax
dbq_meas1 = dn[index]
plt.errorbar(index, bq_meas1, yerr=dbq_meas1)
bq_exp1 = 335.6E+3  # Expected rate of Cs-137 source
br1 = 0.944  # branching ratio of gamma emission for Cs-137
energy1 = 662E+3  # Expected peak position of Cs-137 source
eff1 = bq_meas1 / (bq_exp1 * br1) * 100
deff1 = dbq_meas1 / (bq_exp1 * br1) * 100

print(f'Bin {index} corresponds to 662 keV')
print(f'Efficiency at {energy1} bq is ({eff1:.4f} +/- {deff1:.4f})%')

eff_arr1 = [energy1, eff1, deff1]
corr_arr1 = [index, energy1]
# Out:
# Bin 5247 corresponds to 662 keV
# Efficiency at 662000.0 bq is (0.0147 +/- 0.0001)%

# %% [markdown]
# # Sample 2: Ba-133
# Expect peaks at 276, 302, 356, and 383 keV (and a sum peak at 436 keV)

# %%
filepath = 'data/ba133_x10.csv'
duration = 115  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n # counts/s
dn = np.sqrt(df['n']) / duration

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Ba-133')

bq_meas0 = np.array([])
dbq_meas0 = np.array([])
indices = np.array([])

search_indices = np.array([[2100, 2250], [2250, 2500], [2700, 2900], [2950, 3200]])
for i in range(4):
    lower_idx = search_indices[i, 0]
    upper_idx = search_indices[i, 1]

    y = n[lower_idx:upper_idx]
    index = y.argmax() + lower_idx
    pmax = np.amax(y)
    dpmax = dn[index]
    plt.errorbar(index, pmax, yerr=dpmax)
    
    bq_meas0 = np.append(bq_meas0, pmax)
    dbq_meas0 = np.append(dbq_meas0, dpmax)
    indices = np.append(indices, index)
    
plt.axvspan(ch[search_indices[0, 0]], ch[search_indices[0, 1]], color=cs[1], alpha=0.3)
plt.axvspan(ch[search_indices[1, 0]], ch[search_indices[1, 1]], color=cs[2], alpha=0.3)
plt.axvspan(ch[search_indices[2, 0]], ch[search_indices[2, 1]], color=cs[3], alpha=0.3)
plt.axvspan(ch[search_indices[3, 0]], ch[search_indices[3, 1]], color=cs[4], alpha=0.3)
print(f'Bins: {indices}')
# plt.axhline(amax, color="coral")
# plt.axvline(index, color="coral")
plt.xlim(0, 5000)

print(f'Intensities: {bq_meas0}')

bq_exp0 = 7.32E+3  # Expected rate of Ba-133 source [bq]
br0 = np.array([0.07164, 0.1833, 0.6205, 0.0894, ])  # Expected branching ratios for the 4 Ba-133 peaks
energy0 = np.array([276.4, 302.851, 356.013, 383.848]) * 1E+3  # Expected peak positions of Ba-133 source [eV]
eff0 = bq_meas0 / (bq_exp0 * br0) * 100
deff0 = dbq_meas0 / (bq_exp0 * br0) * 100

print(f'Energies: {energy0}')
print(f'Efficiencies: {eff0}')
print(f'Efficiency errors: {deff0}')

eff_arr0 = [energy0, eff0, deff0]
corr_arr0 = [indices, energy0]
# Out:
# Bins: [2198. 2403. 2826. 3044.]
# Intensities: [0.59130435 1.19073713 2.92930035 0.58204148]
# Energies: [276400. 302851. 356013. 383848.]
# Efficiencies: [0.11275723 0.08874468 0.06449277 0.08894168]
# Efficiency errors: [0.01367382 0.00758558 0.00351451 0.01087655]

# %% [markdown]
# # Sample 3: Am-241
# Peak expected at 59 keV

# %%
filepath = 'data/am241_x10.csv'
duration = 386  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n # counts/s
dn = np.sqrt(df['n']) / duration

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Am-241')

lower_idx = 150
upper_idx = 1000

y = n[lower_idx:upper_idx]
amax = np.amax(y)
index = y.argmax() + lower_idx

plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[2], alpha=0.3)
# plt.axhline(amax, color=c[2])
# plt.axvline(index, color=c[2])
plt.xlim(0, 5000)

bq_meas2 = amax
dbq_meas2 = dn[index]
plt.errorbar(index, bq_meas2, yerr=dbq_meas2, fmt='k.')
bq_exp2 = 31.89E+3  # Expected disintegration rate of Am-241 source
br2 = 0.359  # Expected branching ratio for 59 keV peak of Am-241
energy2 = 59E+3  # Expected peak position of Am-241 source
eff2 = bq_meas2 / (bq_exp2 * br2) * 100
deff2 = dbq_meas2 / (bq_exp2 * br2) * 100

print(f'Bin {index} corresponds to {energy2} keV')
print(f'Efficiency at {energy2} bq is {eff2:.3f}%')

eff_arr2 = [energy2, eff2, deff2]
corr_arr2 = [index, energy2]
# Out:
# Bin 475 corresponds to 59000.0 keV
# Efficiency at 59000.0 bq is 0.006%

# %% [markdown]
# # Background data (March 21)

# %%
filepath = 'data/background_2.csv'
duration = 1059  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

bg_ch = df['ch']  # bin
bg_n2 = df['n'] / duration  # counts/s

# %% [markdown]
# # Sample 4: Na-22
# Peaks expected at 511 keV and 1274 keV

# %%
filepath = 'data/na22_x10.csv'
duration = 802  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n2 # counts/s
dn = np.sqrt(df['n']) / duration

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Na-22')

lower_idx = 3500
upper_idx = 4500
plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[3], alpha=0.3)

y = n[lower_idx:upper_idx]
amax1 = np.amax(y)
index1 = y.argmax() + lower_idx

lower_idx = 8000
upper_idx = 9000
plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[4], alpha=0.3)

y = n[lower_idx:upper_idx]
amax2 = np.amax(y)
index2 = y.argmax() + lower_idx

# plt.axhline(amax, color="coral")
# plt.axvline(index, color="coral")

bq_meas3 = np.array([amax1, amax2])
dbq_meas3 = np.array([dn[index1], dn[index2]])
plt.errorbar([index1, index2], bq_meas3, yerr=dbq_meas3, fmt='.k')
bq_exp3 = 3.24E+3  # Expected rate of Co-60 source
br3 = np.array([1.78, 0.9994])  # Expected branching ratios for the 2 Na-22 peaks
energy3 = np.array([511E+3, 1274E+3])  # Expected peak positions of Co-60 source
eff3 = bq_meas3 / (bq_exp3 * br3) * 100
deff3 = dbq_meas3 / (bq_exp3 * br3) * 100

print(f'Bin {index1} corresponds to {energy3[0]} keV')
print(f'Bin {index2} corresponds to {energy3[1]} keV')
print(f'Efficiency at {energy3[0]} bq is {eff3[0]:.3f}%')
print(f'Efficiency at {energy3[1]} bq is {eff3[1]:.3f}%')

eff_arr3 = [energy3, eff3, deff3]
corr_arr3 = [[index1, index2], energy3]
# Out:
# Bin 4047 corresponds to 511000.0 keV
# Bin 8622 corresponds to 1274000.0 keV
# Efficiency at 511000.0 bq is 0.043%
# Efficiency at 1274000.0 bq is 0.010%

# %% [markdown]
# # Sample 5: Co-60
# Peaks expected at 1173.2 keV and 1332.5 keV

# %%
filepath = 'data/co60_x10.csv'
duration = 826  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n2 # counts/s

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Co-60')

lower_idx = 8000
upper_idx = 8500
plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[5], alpha=0.3)

y = n[lower_idx:upper_idx]
amax1 = np.amax(y)
index1 = y.argmax() + lower_idx

lower_idx = upper_idx
upper_idx = 9000
plt.axvspan(ch[lower_idx], ch[upper_idx], color=cs[6], alpha=0.3)

y = n[lower_idx:upper_idx]
amax2 = np.amax(y)
index2 = y.argmax() + lower_idx

# plt.axhline(amax, color="coral")
# plt.axvline(index, color="coral")

bq_meas4 = np.array([amax1, amax2])
dbq_meas4 = np.array([dn[index1], dn[index2]])
plt.errorbar([index1, index2], bq_meas4, yerr=dbq_meas4, fmt='.k')

bq_exp4 = 3.24E+3  # Expected rate of Co-60 source
br4 = np.array([0.999736, 0.999856])  # Branching ratios for the 2 peaks of Co-60
energy4 = np.array([1173.2E+3, 1332.5E+3])  # Expected peak positions of Co-60 source
eff4 = bq_meas4 / (bq_exp4 * br4) * 100
deff4 = dbq_meas4 / (bq_exp4 * br4) * 100

print(f'Bin {index1} corresponds to {energy4[0]} keV')
print(f'Bin {index2} corresponds to {energy4[1]} keV')
print(f'Efficiency at {energy4[0]} bq is {eff4[0]:.3f}%')
print(f'Efficiency at {energy4[1]} bq is {eff4[1]:.3f}%')

eff_arr4 = [energy4, eff4, deff4]
corr_arr4 = [[index1, index2], energy4]
# Out:
# Bin 8287 corresponds to 1173200.0 keV
# Bin 8789 corresponds to 1332500.0 keV
# Efficiency at 1173200.0 bq is 0.007%
# Efficiency at 1332500.0 bq is 0.005%

# %% [markdown]
# # Sample 6: Co-57
# Peaks expected at 122 keV (85.60%) and 136 keV (10.68%)

# %%
filepath = 'data/co57_x10.csv'
duration = 1157  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n # counts/s
dn = np.sqrt(df['n']) / duration

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Co-57')

bq_meas5 = np.array([])
dbq_meas5 = np.array([])
indices = np.array([])

search_indices = np.array([[900, 1000], [1000, 1200]])
for i in range(2):
    lower_idx = search_indices[i, 0]
    upper_idx = search_indices[i, 1]

    y = n[lower_idx:upper_idx]
    index = y.argmax() + lower_idx
    pmax = np.amax(y)
    dpmax = np.sqrt(dn[index])
    bq_meas5 = np.append(bq_meas5, pmax)
    dbq_meas5 = np.append(dbq_meas5, dpmax)
    indices = np.append(indices, index)
    
plt.axvspan(ch[search_indices[0, 0]], ch[search_indices[0, 1]], color=cs[0], alpha=0.3)
plt.axvspan(ch[search_indices[1, 0]], ch[search_indices[1, 1]], color=cs[1], alpha=0.3)
print(f'Bins: {indices}')
# plt.axhline(amax, color="coral")
# plt.axvline(index, color="coral")
plt.xlim(0, 5000)
plt.errorbar(indices, bq_meas5, yerr=dbq_meas5, fmt='k.')

print(f'Intensities: {bq_meas5}')

bq_exp5 = 74.57E+3  # Expected rate of Co-57 source [bq]
br5 = np.array([0.8560, 0.1068])  # Expected branching ratios for the 4 Co-57 peaks
energy5 = np.array([122.06065, 136.473]) * 1E+3  # Expected peak positions of Co-57 source [eV]
eff5 = bq_meas5 / (bq_exp5 * br5) * 100
deff5 = dbq_meas5 / (bq_exp5 * br5) * 100

print(f'Energies: {energy5}')
print(f'Efficiencies: {eff5}')
print(f'Eff errors: {deff5}')

eff_arr5 = [energy5, eff5, deff5]
corr_arr5 = [indices, energy5]
# Out:
# Bins: [ 969. 1084.]
# Intensities: [120.38953108  14.17229363]
# Energies: [122060.65 136473.  ]
# Efficiencies: [0.18860396 0.17795277]
# Eff errors: [0.00088977 0.0041773 ]

# %%
filepath = 'data/pulser_x10.csv'
duration = 425  # s

df = pd.read_csv(filepath, header=7)
df.columns = ['ch', 'n']

ch = df['ch']  # bin
n = df['n'] / duration - bg_n # counts/s

plt.plot(ch, n, 'k')
plt.xlabel('Bin')
plt.ylabel('Counts/s')
plt.yscale('log')
plt.title('Pulser data')

bq_meas0 = np.array([])
pulser_i = np.array([])

settings = np.array([2, 5, 10, 20, 50, 100])
search_indices = np.array([[600, 900], [1700, 2100], [3500, 4000], [7000, 7500], [10500, 11500], [12500, 13500]])
for i in range(len(search_indices)):
    lower_idx = search_indices[i, 0]
    upper_idx = search_indices[i, 1]

    y = n[lower_idx:upper_idx]
    bq_meas0 = np.append(bq_meas0, np.amax(y))
    pulser_i = np.append(pulser_i, y.argmax() + lower_idx)
    
plt.axvspan(ch[search_indices[0, 0]], ch[search_indices[0, 1]], color=cs[0], alpha=0.3)
plt.text(200, 100, f'x{settings[0]}')
plt.axvspan(ch[search_indices[1, 0]], ch[search_indices[1, 1]], color=cs[1], alpha=0.3)
plt.text(1500, 100, f'x{settings[1]}')
plt.axvspan(ch[search_indices[2, 0]], ch[search_indices[2, 1]], color=cs[2], alpha=0.3)
plt.text(3200, 100, f'x{settings[2]}')
plt.axvspan(ch[search_indices[3, 0]], ch[search_indices[3, 1]], color=cs[3], alpha=0.3)
plt.text(6700, 100, f'x{settings[3]}')
plt.axvspan(ch[search_indices[4, 0]], ch[search_indices[4, 1]], color=cs[4], alpha=0.3)
plt.text(10300, 100, f'x{settings[4]}')
plt.axvspan(ch[search_indices[5, 0]], ch[search_indices[5, 1]], color=cs[5], alpha=0.3)
plt.text(12000, 100, f'x{settings[5]}')

print(pulser_i)
print(const.e)
e0 = 500E-3  *const.e / 2  # Original pulse with x2 setting read 500 mV
pulser_e = e0 * settings
print(pulser_e)
# Out:
# [  738.  1932.  3768.  7218. 11127. 12982.]
# 1.602176634e-19
# [8.01088317e-20 2.00272079e-19 4.00544158e-19 8.01088317e-19
#  2.00272079e-18 4.00544158e-18]

# %% [markdown]
# ## Calibration plots

# %%
from scipy.optimize import curve_fit

# %%
bins = np.sort(np.concatenate((corr_arr0[0], corr_arr1[0], corr_arr3[0], corr_arr4[0], corr_arr5[0]), axis=None))
energies = np.sort(np.concatenate((corr_arr0[1], corr_arr1[1], corr_arr3[1], corr_arr4[1], corr_arr5[1]), axis=None))
plt.plot(bins, energies / 1000, 'kx', label="Measured peaks")

# Have an initial guess as to what the values of the parameters are
x = bins[0:8]
y = energies[0:8] / 1000
m_guess = 1
b_guess = 1

# Fit the function m * x + b to x and y
popt, pcov = curve_fit(
    lambda x, m, b: m * x + b,
    x, y, p0=(m_guess, b_guess)
)

# The optimised values of the parameters are
m = popt[0]
b = popt[1]

dm = np.sqrt(pcov[0][0])
db = np.sqrt(pcov[1][1])

ss_res = np.sum((y-(m * x + b))**2)
ss_tot = np.sum((y - np.mean(y)) ** 2)
# r-squared
r2 = 1 - (ss_res / ss_tot)
print(r2)
print(ss_res)
print(ss_tot)
plt.plot(x, m * x + b, '--', color=cs[3], label="Fit (linear)")
plt.xlabel("Bin")
plt.ylabel("Energy (keV)")
plt.legend()
# Out:
# 0.9999965493100865
# 0.7913552652184845
# 229332.4769984322

# %%
fig, ax = plt.subplots(1, 2, figsize=(9, 3.5))
ax[0].plot(corr_arr0[0], corr_arr0[1] / 1000, 'x', color=cs[0], label='Ba-133')
ax[0].plot(corr_arr1[0], corr_arr1[1] / 1000, 'x', color=cs[1], label='Cs-137')
# ax[0].plot(corr_arr2[0], corr_arr2[1] / 1000, 'x', color=cs[2], label='Am-241')
ax[0].plot(corr_arr3[0], corr_arr3[1] / 1000, 'x', color=cs[3], label='Na-22')
ax[0].plot(corr_arr4[0], corr_arr4[1] / 1000, 'x', color=cs[4], label='Co-60')
ax[0].plot(corr_arr5[0], corr_arr5[1] / 1000, 'x', color=cs[5], label='Co-57')

ax[0].plot(x, m * x + b, '--k', label="Fit (linear)")

ax[0].set_title('Known samples')
ax[0].set_xlabel('Channel (N)')
ax[0].set_ylabel('Energy (E) [keV]')
# plt.title('Bin correlation')
ax[0].text(1000, 800, f"$E = ({m:.4f}\pm{dm:.4f})N+({b:.1f}\pm{db:.1f})$", fontsize=10)
ax[0].legend(ncol=2, loc='upper left')

ax[1].plot(pulser_i, pulser_e / 1000, 'x', color=cs[6], label='Pulser')
ax[1].axvspan(0, 6000, color='gray', alpha=0.1)
ax[1].set_title('Pulser measurements')
ax[1].set_xlabel("Channel (N)")
plt.show()

# %%
print(eff_arr0[0])
print(eff_arr0[1])
print(eff_arr0[2])
print(cs)
plt.errorbar(eff_arr0[0] / 1000, eff_arr0[1], yerr=eff_arr0[2], fmt='.', color=cs[0], label='Ba-133')
plt.errorbar(eff_arr1[0] / 1000, eff_arr1[1], yerr=eff_arr1[2], fmt='.', color=cs[1], label='Cs-137')
# plt.plot(eff_arr2[0] / 1000, eff_arr2[1], 'x', color=c[2], label='Am-241')
plt.errorbar(eff_arr3[0] / 1000, eff_arr3[1], yerr=eff_arr3[2], fmt='.', color=cs[3], label='Na-22')
plt.errorbar(eff_arr4[0] / 1000, eff_arr4[1], yerr=eff_arr4[2], fmt='.', color=cs[4], label='Co-60')
plt.errorbar(eff_arr5[0] / 1000, eff_arr5[1], yerr=eff_arr5[2], fmt='.', color=cs[5], label='Co-57')
# Out:
# [276400. 302851. 356013. 383848.]
# [0.11275723 0.08874468 0.06449277 0.08894168]
# [0.01367382 0.00758558 0.00351451 0.01087655]
# ['#006ba6', '#0496ff', '#82a9a1', '#ffbc42', '#ec674e', '#d81159', '#8f2d56']
# <ErrorbarContainer object of 3 artists>

# %%
from scipy.optimize import curve_fit
import operator

# %%
x = np.concatenate((eff_arr0[0], eff_arr1[0], eff_arr3[0], eff_arr4[0], eff_arr5[0]), axis=None) / 1000
y = np.concatenate((eff_arr0[1], eff_arr1[1], eff_arr3[1], eff_arr4[1], eff_arr5[1]), axis=None)
dy = np.concatenate((eff_arr0[2], eff_arr1[2], eff_arr3[2], eff_arr4[2], eff_arr5[2]), axis=None)

L = sorted(zip(x,y,dy), key=operator.itemgetter(0))
x, y, dy = zip(*L)
x = np.array(x)
y = np.array(y)
dy = np.array(dy)

plt.errorbar(x, y, yerr=dy, fmt='x', label="Measured efficiency")

# Have an initial guess as to what the values of the parameters are
a_guess = 0.3
b_guess = 1 / 200
c_guess = 0

# plt.plot(x, a_guess * np.exp(-b_guess * x) + c_guess, '--', label="Guess")

# Fit the function a * np.exp(b * t) + c to x and y
popt, pcov = curve_fit(
    lambda t, a, b, c: a * np.exp(-b * t) + c,
    x, y, p0=(a_guess, b_guess, c_guess), sigma=dy
)

# The optimised values of the parameters are
a = popt[0]
b = popt[1]
c = popt[2]

da = np.sqrt(pcov[0][0])
db = np.sqrt(pcov[1][1])
dc = np.sqrt(pcov[2][2])

xarr = np.linspace(x[0], x[-1], 1000)
plt.plot(xarr, a * np.exp(-b * xarr) + c, '--', label="Fit")
plt.xlabel('Energy [keV]')
plt.ylabel('Efficiency [%]')
plt.title('Detector efficiency')
plt.legend()
plt.show()

print(r"Fit: a exp(-b x) + c")
print(f"a = {a} \t da = {da}")
print(f"b = {b} \t db = {db}")
print(f"c = {c} \t dc = {dc}")
# Out:
# Fit: a exp(-b x) + c
# a = 0.35638794597024515 	 da = 0.01700380902167981
# b = 0.005427010208413421 	 db = 0.00022789278528330805
# c = 0.005506747400341094 	 dc = 0.000681917335069392

# %%
plt.errorbar(eff_arr0[0] / 1000, eff_arr0[1], yerr=eff_arr0[2], fmt='.', color=cs[0], label='Ba-133')
plt.errorbar(eff_arr1[0] / 1000, eff_arr1[1], yerr=eff_arr1[2], fmt='.', color=cs[1], label='Cs-137')
# plt.plot(eff_arr2[0] / 1000, eff_arr2[1], 'x', color=c[2], label='Am-241')
plt.errorbar(eff_arr3[0] / 1000, eff_arr3[1], yerr=eff_arr3[2], fmt='.', color=cs[3], label='Na-22')
plt.errorbar(eff_arr4[0] / 1000, eff_arr4[1], yerr=eff_arr4[2], fmt='.', color=cs[4], label='Co-60')
plt.errorbar(eff_arr5[0] / 1000, eff_arr5[1], yerr=eff_arr5[2], fmt='.', color=cs[5], label='Co-57')

fit = a * np.exp(-b * xarr) + c
plt.plot(xarr, fit, 'k--', label="Fit")
plt.xlabel('Energy [keV]')
plt.ylabel('Efficiency [%]')
# plt.title('Detector efficiency')
plt.legend()
plt.show()

print(r"Fit: a exp(-b x) + c")
print(f"a = {a} \t da = {da}")
print(f"b = {b} \t db = {db}")
print(f"c = {c} \t dc = {dc}")
# Out:
# Fit: a exp(-b x) + c
# a = 0.35638794597024515 	 da = 0.01700380902167981
# b = 0.005427010208413421 	 db = 0.00022789278528330805
# c = 0.005506747400341094 	 dc = 0.000681917335069392

# %%
fit = fit = a * np.exp(-b * x) + c
ss_res = np.sum((y-fit)**2)
ss_tot = np.sum((y - np.mean(y)) ** 2)
# r-squared
r2 = 1 - (ss_res / ss_tot)
print(r2)
print(ss_res)
print(ss_tot)
# Out:
# 0.9358965745707192
# 0.002801725542902442
# 0.04370633120055835

# %%
effs = pd.read_csv('detector_eff.csv', header=None)
effs.columns = ['Ep', 'sigma']
plt.plot(effs['Ep'] / 1000, effs['sigma'])
plt.yscale("log")
plt.xlabel("Photon energy $E_p$ [keV]")
plt.ylabel("$\sigma$")  # Need to convert this to detector efficiency somehow
plt.xlim(0, 1300)
# Out:
# (0.0, 1300.0)
