# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from os import listdir
from os.path import isfile, join

# %%
filepath = 'data/feb28/16011_water_tau03.csv'
tau = 0.003 # s

df = pd.read_csv(filepath, header=None)
df.columns = ['Header', 'Headerdata', 'n1', 't', 'V']
df = df.drop(columns=['n1'])

# %%
times = df['t'].to_numpy()
volts = df['V'].to_numpy()
    
lower_val = 2 * tau - 0.5 * tau
upper_val = 2 * tau + 0.5 * tau
    
lower_idx = (np.abs(times - lower_val)).argmin()
upper_idx = (np.abs(times - upper_val)).argmin()

y = volts[lower_idx:upper_idx]
amax = np.amax(y)
avg = np.mean(y)
    
plt.plot(times, volts)
plt.axvspan(times[lower_idx], times[upper_idx], color="orange", alpha=0.3)
plt.axhline(avg, color="red")
plt.axhline(amax, color="magenta")
ax.set_xlabel("Time [s]")
ax.set_title(f"tau = {tau:.3f} [s]")
# Out:
# Text(0.5, 1.0, 'tau = 0.003 [s]')
